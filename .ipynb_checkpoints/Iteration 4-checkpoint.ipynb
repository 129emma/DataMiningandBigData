# %% [markdown]
# # Iteration 4_INFOSYS 722
# yzhb363 Emma

# %% [markdown]
# - This part starts from Data Preparation of Iteration 4
# - I will number each relevant cell as answers
# - please run **all cells** at the same time, since all packages are imported at the begining

# %%
import findspark
findspark.init('/home/ubuntu/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql.functions import col

spark = SparkSession.builder.appName('iteration4').getOrCreate()

# %%
# Import pandas.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import dataset 
dataFrame = spark.read.csv('Dataset/data.csv',header=True,inferSchema=True)

# %%
# Show the dataset
pd.DataFrame(dataFrame.take(20), columns=dataFrame.columns)
# Out:
#                     ANZSOCGroup         MapDetailName            Region  \
# 0       AggravatedSexualAssault        HillcrestWest.     WaikatoRegion
# 1   Non-AggravatedSexualAssault     TeAwamutuCentral.     WaikatoRegion
# 2       AggravatedSexualAssault        TotaraHeights.    AucklandRegion
# 3       AggravatedSexualAssault         FlaxmereEast.  Hawke'sBayRegion
# 4       AggravatedSexualAssault               Wairoa.  Hawke'sBayRegion
# 5       AggravatedSexualAssault               Wairoa.  Hawke'sBayRegion
# 6       AggravatedSexualAssault            Brentwood.  WellingtonRegion
# 7       AggravatedSexualAssault         GlenEdenEast.    AucklandRegion
# 8       AggravatedSexualAssault          GraftonEast.    AucklandRegion
# 9       AggravatedSexualAssault        PukekoheNorth.    AucklandRegion
# 10      AggravatedSexualAssault                 Wiri.    AucklandRegion
# 11      AggravatedSexualAssault           MellonsBay.    AucklandRegion
# 12      AggravatedSexualAssault         StarlingPark.    AucklandRegion
# 13      AggravatedSexualAssault  AucklandHarbourside.    AucklandRegion
# 14      AggravatedSexualAssault  AucklandCentralWest.    AucklandRegion
# 15      AggravatedSexualAssault  AucklandCentralEast.    AucklandRegion
# 16  Non-AggravatedSexualAssault      TakapunaCentral.    AucklandRegion
# 17      AggravatedSexualAssault      CathedralSquare.  CanterburyRegion
# 18      AggravatedSexualAssault      CathedralSquare.  CanterburyRegion
# 19  Non-AggravatedSexualAssault          NewtownEast.  WellingtonRegion
#
#     NumberofVictimisations  NumberofRecords OccurrenceDayOfWeek  \
# 0                        1                1             UNKNOWN
# 1                        1                1                 Sun
# 2                        1                1                 Tue
# 3                        1                1                 Sun
# 4                        1                1             UNKNOWN
# 5                        1                1             UNKNOWN
# 6                        1                1             UNKNOWN
# 7                        1                1                 Mon
# 8                        1                1                 Mon
# 9                        1                1                 Wed
# 10                       1                1                 Sat
# 11                       1                1             UNKNOWN
# 12                       1                1                 Mon
# 13                       1                1                 Mon
# 14                       1                1                 Sat
# 15                       1                1             UNKNOWN
# 16                       1                1                 Fri
# 17                       1                1                 Tue
# 18                       1                1                 Tue
# 19                       3                1             UNKNOWN
#
#            Weapon YearMonth
# 0   NotApplicable   1/07/14
# 1   NotApplicable   1/07/14
# 2       NotStated   1/07/14
# 3       NotStated   1/07/14
# 4       NotStated   1/07/14
# 5       NotStated   1/07/14
# 6       NotStated   1/07/14
# 7       NotStated   1/07/14
# 8       NotStated   1/07/14
# 9   NotApplicable   1/09/14
# 10  NotApplicable   1/09/14
# 11  NotApplicable   1/09/14
# 12  NotApplicable   1/09/14
# 13  NotApplicable   1/09/14
# 14      NotStated   1/09/14
# 15      NotStated   1/09/14
# 16  NotApplicable   1/09/14
# 17  NotApplicable   1/09/14
# 18      NotStated   1/09/14
# 19  NotApplicable   1/09/14

# %% [markdown]
# ## 2.3 Data Exporation

# %%
# Computer summary of the data
dataFrame.describe().show()

# Number of AggrabatedSexualAssault report
aggSexAssuaultTable = dataFrame[dataFrame.ANZSOCGroup.isin("AggravatedSexualAssault")]
print('\n' + "Total of aggravatedSexualAssault reports:", aggSexAssuaultTable.count())

# Number of Non-AggravatedSexualAssault report
nonAggravatedSexualAssault = dataFrame[dataFrame.ANZSOCGroup.isin("Non-AggravatedSexualAssault")]
print('\n' + "Total of Non-AggravatedSexualAssault reports:", nonAggravatedSexualAssault.count())
# Out:
# +-------+--------------------+-------------+---------------+----------------------+---------------+-------------------+-----------+---------+
# |summary|         ANZSOCGroup|MapDetailName|         Region|NumberofVictimisations|NumberofRecords|OccurrenceDayOfWeek|     Weapon|YearMonth|
# +-------+--------------------+-------------+---------------+----------------------+---------------+-------------------+-----------+---------+
# |  count|                8354|         7734|           7734|                  8354|           8354|               8354|       8354|     8354|
# |   mean|                null|         null|           null|    0.9547522145080201|            1.0|               null|       null|     null|
# | stddev|                null|         null|           null|      0.52938282883613|            0.0|               null|       null|     null|
# |    min|AggravatedSexualA...|  AbbeyCaves.| AucklandRegion|                     0|              1|                Fri|   Bludgeon|  1/01/15|
# |    max|Non-AggravatedSex...|  YattonPark.|WestCoastRegion|                    36|              1|                Wed|OtherWeapon|  1/12/17|
# +-------+--------------------+-------------+---------------+----------------------+---------------+-------------------+-----------+---------+
#
#
# Total of aggravatedSexualAssault reports: 6199
#
# Total of Non-AggravatedSexualAssault reports: 2155

# %% [markdown]
# ## 3 Data  Preparation
# ### 3.2 To clean the data, issues must be made explicit, then explicitly resolved.

# %%
# Drop null values with their rows
droppedTable = dataFrame.na.drop()

# %%
# Remove the columns that do not need 
dropList = ['MapDetailName','NumberofVictimisations','NumberofRecords','Weapon','OccurrenceDayOfWeek']

newData = droppedTable.select([column for column in droppedTable.columns if column not in dropList])

# Drop rows with UNKOWN occurrenceDayofWeek
# cleanTable = droppedTable.filter(~col('OccurrenceDayOfWeek').isin(['UNKNOWN']))

# %%
# Change column name
cleanData = newData.selectExpr('ANZSOCGroup as AssaultType', 'Region as Region', 'YearMonth as Date')

# %%
# Show columns before & after cleaning
# Show orginal columns before cleaning
print("Total data columns before cleaning:", dataFrame.count())
print("Total data columns after cleaning:", cleanData.count())

pd.DataFrame(newData.take(20), columns=cleanData.columns)
# Out:
# Total data columns before cleaning: 8354
# Total data columns after cleaning: 7734
#                     AssaultType            Region     Date
# 0       AggravatedSexualAssault     WaikatoRegion  1/07/14
# 1   Non-AggravatedSexualAssault     WaikatoRegion  1/07/14
# 2       AggravatedSexualAssault    AucklandRegion  1/07/14
# 3       AggravatedSexualAssault  Hawke'sBayRegion  1/07/14
# 4       AggravatedSexualAssault  Hawke'sBayRegion  1/07/14
# 5       AggravatedSexualAssault  Hawke'sBayRegion  1/07/14
# 6       AggravatedSexualAssault  WellingtonRegion  1/07/14
# 7       AggravatedSexualAssault    AucklandRegion  1/07/14
# 8       AggravatedSexualAssault    AucklandRegion  1/07/14
# 9       AggravatedSexualAssault    AucklandRegion  1/09/14
# 10      AggravatedSexualAssault    AucklandRegion  1/09/14
# 11      AggravatedSexualAssault    AucklandRegion  1/09/14
# 12      AggravatedSexualAssault    AucklandRegion  1/09/14
# 13      AggravatedSexualAssault    AucklandRegion  1/09/14
# 14      AggravatedSexualAssault    AucklandRegion  1/09/14
# 15      AggravatedSexualAssault    AucklandRegion  1/09/14
# 16  Non-AggravatedSexualAssault    AucklandRegion  1/09/14
# 17      AggravatedSexualAssault  CanterburyRegion  1/09/14
# 18      AggravatedSexualAssault  CanterburyRegion  1/09/14
# 19  Non-AggravatedSexualAssault  WellingtonRegion  1/09/14

# %% [markdown]
# ### 3.3 Data must be appropriately constructed through the creation of new features/variables, and/or data repositories/tables.

# %%
from pyspark.sql.functions import format_number, col

cleanData.printSchema()
# Out:
# root
#  |-- AssaultType: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Date: string (nullable = true)

# %%
# Group by Assault type 
cleanData.groupBy('AssaultType').count().orderBy(col('count').desc()).toPandas()
# Out:
#                    AssaultType  count
# 0      AggravatedSexualAssault   5657
# 1  Non-AggravatedSexualAssault   2077

# %%
# Group by Region 
cleanData.groupBy('Region').count().orderBy(col('count').desc()).toPandas()
# Out:
#                      Region  count
# 0            AucklandRegion   2354
# 1          CanterburyRegion   1025
# 2          WellingtonRegion    829
# 3             WaikatoRegion    751
# 4         BayofPlentyRegion    491
# 5   Manawatu-WanganuiRegion    468
# 6               OtagoRegion    402
# 7          Hawke'sBayRegion    397
# 8           NorthlandRegion    290
# 9            TaranakiRegion    197
# 10          SouthlandRegion    125
# 11             NelsonRegion    124
# 12           GisborneRegion     99
# 13             TasmanRegion     67
# 14        MarlboroughRegion     64
# 15          WestCoastRegion     51

# %%
# Top 20 assaults happen date
cleanData.groupBy('Date').count().orderBy(col('count').desc()).toPandas()
# Out:
#        Date  count
# 0   1/03/17    214
# 1   1/05/17    186
# 2   1/03/18    185
# 3   1/11/17    183
# 4   1/12/17    181
# 5   1/02/17    179
# 6   1/06/18    177
# 7   1/02/16    174
# 8   1/03/16    174
# 9   1/05/18    174
# 10  1/06/17    173
# 11  1/08/17    171
# 12  1/11/16    168
# 13  1/02/18    167
# 14  1/11/14    165
# 15  1/07/18    163
# 16  1/03/15    163
# 17  1/04/18    162
# 18  1/10/15    162
# 19  1/04/17    159
# 20  1/10/16    156
# 21  1/10/17    154
# 22  1/04/16    154
# 23  1/05/16    154
# 24  1/09/16    153
# 25  1/07/16    153
# 26  1/11/15    152
# 27  1/01/17    151
# 28  1/09/17    151
# 29  1/08/14    151
# 30  1/12/16    148
# 31  1/07/14    147
# 32  1/09/15    146
# 33  1/09/14    146
# 34  1/08/15    145
# 35  1/05/15    145
# 36  1/12/15    144
# 37  1/01/16    144
# 38  1/01/18    143
# 39  1/06/15    140
# 40  1/10/14    140
# 41  1/08/16    139
# 42  1/06/16    135
# 43  1/01/15    135
# 44  1/08/18    135
# 45  1/07/15    131
# 46  1/07/17    118
# 47  1/12/14    116
# 48  1/04/15    115
# 49  1/02/15    113

# %% [markdown]
# ### Model Pipeline

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler

label_stringIdx = StringIndexer(inputCol = 'AssaultType', outputCol = "label")
region_indexer = StringIndexer(inputCol='Region',outputCol='regionIndex')
date_indexer = StringIndexer(inputCol='Date',outputCol='dateIndex')

# OnehotEncode region
region_encoder = OneHotEncoder(inputCol='regionIndex',outputCol='regionVec')
date_encoder = OneHotEncoder(inputCol='dateIndex',outputCol='dateVec')

# Set it as feature
assembler = VectorAssembler(inputCols=['regionVec','dateVec'], outputCol="features")

# %%
# Get those into pipeline
pipeline = Pipeline(stages=[label_stringIdx, region_indexer, date_indexer, region_encoder, date_encoder,assembler])

# Fit the pipeline to training documents.
pipelineFit = pipeline.fit(cleanData)
pipe_df = pipelineFit.transform(cleanData)
pipe_df.show(5)
# Out:
# +--------------------+----------------+-------+-----+-----------+---------+--------------+---------------+--------------------+
# |         AssaultType|          Region|   Date|label|regionIndex|dateIndex|     regionVec|        dateVec|            features|
# +--------------------+----------------+-------+-----+-----------+---------+--------------+---------------+--------------------+
# |AggravatedSexualA...|   WaikatoRegion|1/07/14|  0.0|        3.0|     31.0|(15,[3],[1.0])|(49,[31],[1.0])|(64,[3,46],[1.0,1...|
# |Non-AggravatedSex...|   WaikatoRegion|1/07/14|  1.0|        3.0|     31.0|(15,[3],[1.0])|(49,[31],[1.0])|(64,[3,46],[1.0,1...|
# |AggravatedSexualA...|  AucklandRegion|1/07/14|  0.0|        0.0|     31.0|(15,[0],[1.0])|(49,[31],[1.0])|(64,[0,46],[1.0,1...|
# |AggravatedSexualA...|Hawke'sBayRegion|1/07/14|  0.0|        7.0|     31.0|(15,[7],[1.0])|(49,[31],[1.0])|(64,[7,46],[1.0,1...|
# |AggravatedSexualA...|Hawke'sBayRegion|1/07/14|  0.0|        7.0|     31.0|(15,[7],[1.0])|(49,[31],[1.0])|(64,[7,46],[1.0,1...|
# +--------------------+----------------+-------+-----+-----------+---------+--------------+---------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ### Partition Training & Test sets

# %%
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# Split data into train and test. 
trainingData, testData = pipe_df.randomSplit([0.7,0.3])
print("Training Dataset Count: " + str(trainingData.count()))
print("Test Dataset Count: " + str(testData.count()))

# Instantiate the model.
lr_model = LogisticRegression(featuresCol='features',labelCol='label')

# Fit the model.
lr_model = lr_model.fit(trainingData)

# And evaluate the model using the test data.
logRePredictions = lr_model.transform(testData)
# Out:
# Training Dataset Count: 5455
# Test Dataset Count: 2279

# %% [markdown]
# ## 7 Data Mining
# ### Model Training and Evaluation
# - Logistic Regression using Count Vector Features

# %%
lr = LogisticRegression(maxIter=20, regParam=0.3, elasticNetParam=0)
lrModel = lr.fit(trainingData)
predictions = lrModel.transform(testData)

predictions.filter(predictions['prediction'] == 0) \
    .select('AssaultType','Region','Date','label','probability','prediction') \
    .orderBy("probability", ascending=False) \
    .show(n = 10, truncate = 30)
# Out:
# +-----------------------+-----------------+-------+-----+------------------------------+----------+
# |            AssaultType|           Region|   Date|label|                   probability|prediction|
# +-----------------------+-----------------+-------+-----+------------------------------+----------+
# |AggravatedSexualAssault|     TasmanRegion|1/03/17|  0.0|[0.7938445137971671,0.20615...|       0.0|
# |AggravatedSexualAssault|     TasmanRegion|1/03/17|  0.0|[0.7938445137971671,0.20615...|       0.0|
# |AggravatedSexualAssault|     TasmanRegion|1/03/17|  0.0|[0.7938445137971671,0.20615...|       0.0|
# |AggravatedSexualAssault|     TasmanRegion|1/03/17|  0.0|[0.7938445137971671,0.20615...|       0.0|
# |AggravatedSexualAssault|  NorthlandRegion|1/06/18|  0.0|[0.7920852176527462,0.20791...|       0.0|
# |AggravatedSexualAssault|  NorthlandRegion|1/06/18|  0.0|[0.7920852176527462,0.20791...|       0.0|
# |AggravatedSexualAssault|  NorthlandRegion|1/06/18|  0.0|[0.7920852176527462,0.20791...|       0.0|
# |AggravatedSexualAssault|  NorthlandRegion|1/06/18|  0.0|[0.7920852176527462,0.20791...|       0.0|
# |AggravatedSexualAssault|  NorthlandRegion|1/06/18|  0.0|[0.7920852176527462,0.20791...|       0.0|
# |AggravatedSexualAssault|MarlboroughRegion|1/10/15|  0.0|[0.791529276659309,0.208470...|       0.0|
# +-----------------------+-----------------+-------+-----+------------------------------+----------+
# only showing top 10 rows

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

evaluator = MulticlassClassificationEvaluator(predictionCol="prediction")
evaluator.evaluate(predictions)
# Out:
# 0.6133420363149663

# %% [markdown]
# - Cross-Validation

# %%
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

lrCrossVa = LogisticRegression(maxIter=20, regParam=0.3, elasticNetParam=0)

# Create ParamGrid for Cross Validation
paramGrid = (ParamGridBuilder()
             # regularization parameter
             .addGrid(lr.regParam, [0.1, 0.3, 0.5]) 
             # Elastic Net Parameter (Ridge = 0)
             .addGrid(lr.elasticNetParam, [0.0, 0.1, 0.2]) 
             .build())
             
# Create 5-fold CrossValidator
cv = CrossValidator(estimator=lr, \
                    estimatorParamMaps=paramGrid, \
                    evaluator=evaluator, \
                    numFolds=5)
cvModel = cv.fit(trainingData)

cVpredictions = cvModel.transform(testData)
# Evaluate best model
cVevaluator = MulticlassClassificationEvaluator(predictionCol="prediction")
cVevaluator.evaluate(cVpredictions)

# %%
predictions.filter(predictions['prediction'] == 0) \
    .select("Descript","Category","probability","label","prediction") \
    .orderBy("probability", ascending=False) \
    .show(n = 10, truncate = 30)

# compute accuracy on the test set
reGevaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",
                                              metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Test set accuracy = " + str(accuracy))

# %%
# Visualising the coefficients. Sort from lowest to highest.
beta = np.sort(lr_model.coefficients)

# Plot the data.
plt.plot(beta)

# Add a label to the data.
plt.ylabel('Beta Coefficients')

# Show the graph. 
plt.show()

# %%
# Let's get a summary of the data.
training_summary = lr_model.summary

# Convert the DataFrame to a Pandas DataFrame.
ROC = training_summary.roc.toPandas()

# Plot the true positive and false positive rates.
plt.plot(ROC['FPR'],ROC['TPR'])

# Define the labels.
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve')
plt.show()

# Print the AUC statistic. 
print('Area Under the Curve: ' + str(training_summary.areaUnderROC))
# Out:
# Area Under the Curve: 0.8729744090219042

# %%
# Convert DataFrame to Pandas DataFrame.
pr = training_summary.pr.toPandas()

# Plot model recall and precision.
plt.plot(pr['recall'],pr['precision'])

# Define the labels and show the graph. 
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.show()

# %% [markdown]
# - Naive Bayes
# **Naive Bayes classifiers are a family of simple probabilistic classifiers based on applying Bayes’ theorem with strong (naive) independence assumptions between the features. **

# %%
from pyspark.ml.classification import NaiveBayes

# Split data into train and test. 
naiBaTrain_data, naiBaTest_data = pipe_df.randomSplit([0.7,0.3])
print("Training Dataset Count: " + str(naiBaTrain_data.count()))
print("Test Dataset Count: " + str(naiBaTest_data.count()))

# create the trainer and set its parameters
nb = NaiveBayes(smoothing=1.0, modelType="multinomial")

# train the model
naiBaModel = nb.fit(naiBaTrain_data)

# select example rows to display.
predictions = naiBaModel.transform(naiBaTest_data)
predictions.show()

# compute accuracy on the test set
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",
                                              metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Test set accuracy = " + str(accuracy))
# Out:
# Training Dataset Count: 4224
# Test Dataset Count: 1833
# Test set accuracy = 0.6972176759410802

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-d54aabea2bb2> in <module>()
# ----> 1 nbSummary = naiBaModel.summary
#       2 ROC = nbSummary.roc.toPandas()
#
# AttributeError: 'NaiveBayesModel' object has no attribute 'summary'
